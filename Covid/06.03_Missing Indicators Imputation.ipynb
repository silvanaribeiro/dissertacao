# %% [markdown]
# ## This notebook inputs the missing values using Missing Indicators

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import MissingIndicator

# %% [markdown]
# #### Choose wether the imputation should be done on the data set with daily or weekly granularity

# %%
INPUT, OUTPUT = 'output/\CompleteCovid', 'output/\MIICovidImputed'

# %%
df = pd.read_csv(r'output\/CompleteCovid.csv',index_col=0)
df_train = df.loc['2020-01-22 09:00:00':'2020-02-26 02:00:00'].dropna(how='all', axis=1) #Selecting training data
df_test = df.loc['2020-02-26 02:30:00':, df_train.columns] #Selecting test data
df = df_train

# %%
indicator = MissingIndicator(missing_values=np.nan, features="all")

# %%
indicator.fit(df)
mask_all = indicator.transform(df)
mask_test_all = indicator.transform(df_test)

# %%
df_masks = pd.DataFrame(data=mask_all, index=df.index, columns=df.columns)
df_test_masks = pd.DataFrame(data=mask_test_all, index=df_test.index, columns=df_test.columns)

# %%
df_masks = df_masks.add_prefix('MI_')
df_test_masks = df_test_masks.add_prefix('MI_')

# %%
df_final = pd.concat([df, df_masks], axis=1, join='outer')
df_test_final = pd.concat([df_test, df_test_masks], axis=1, join='outer')

# %%
df_final.head()
# Out:
#                      Asia_confirmed_cases  Asia_deaths  Asia_recovered  \
# update_time
# 2020-01-22 09:00:00                 270.0          6.0             0.0
# 2020-01-22 09:30:00                   NaN          NaN             NaN
# 2020-01-22 10:00:00                   NaN          NaN             NaN
# 2020-01-22 10:30:00                   NaN          NaN             NaN
# 2020-01-22 11:00:00                   NaN          NaN             NaN
#
#                      Europe_confirmed_cases  Europe_deaths  Europe_recovered  \
# update_time
# 2020-01-22 09:00:00                     NaN            NaN               NaN
# 2020-01-22 09:30:00                     NaN            NaN               NaN
# 2020-01-22 10:00:00                     NaN            NaN               NaN
# 2020-01-22 10:30:00                     NaN            NaN               NaN
# 2020-01-22 11:00:00                     NaN            NaN               NaN
#
#                      Americas_confirmed_cases  Americas_deaths  \
# update_time
# 2020-01-22 09:00:00                       NaN              NaN
# 2020-01-22 09:30:00                       NaN              NaN
# 2020-01-22 10:00:00                       NaN              NaN
# 2020-01-22 10:30:00                       NaN              NaN
# 2020-01-22 11:00:00                       NaN              NaN
#
#                      Americas_recovered  Oceania_confirmed_cases  ...  \
# update_time                                                       ...
# 2020-01-22 09:00:00                 NaN                      NaN  ...
# 2020-01-22 09:30:00                 NaN                      NaN  ...
# 2020-01-22 10:00:00                 NaN                      NaN  ...
# 2020-01-22 10:30:00                 NaN                      NaN  ...
# 2020-01-22 11:00:00                 NaN                      NaN  ...
#
#                      MI_Europe_recovered  MI_Americas_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                 True                         True
# 2020-01-22 09:30:00                 True                         True
# 2020-01-22 10:00:00                 True                         True
# 2020-01-22 10:30:00                 True                         True
# 2020-01-22 11:00:00                 True                         True
#
#                      MI_Americas_deaths  MI_Americas_recovered  \
# update_time
# 2020-01-22 09:00:00                True                   True
# 2020-01-22 09:30:00                True                   True
# 2020-01-22 10:00:00                True                   True
# 2020-01-22 10:30:00                True                   True
# 2020-01-22 11:00:00                True                   True
#
#                      MI_Oceania_confirmed_cases  MI_Oceania_deaths  \
# update_time
# 2020-01-22 09:00:00                        True               True
# 2020-01-22 09:30:00                        True               True
# 2020-01-22 10:00:00                        True               True
# 2020-01-22 10:30:00                        True               True
# 2020-01-22 11:00:00                        True               True
#
#                      MI_Oceania_recovered  MI_Africa_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                  True                       True
# 2020-01-22 09:30:00                  True                       True
# 2020-01-22 10:00:00                  True                       True
# 2020-01-22 10:30:00                  True                       True
# 2020-01-22 11:00:00                  True                       True
#
#                      MI_Africa_deaths  MI_Africa_recovered
# update_time
# 2020-01-22 09:00:00              True                 True
# 2020-01-22 09:30:00              True                 True
# 2020-01-22 10:00:00              True                 True
# 2020-01-22 10:30:00              True                 True
# 2020-01-22 11:00:00              True                 True
#
# [5 rows x 30 columns]

# %%
df.head()
# Out:
#                      Asia_confirmed_cases  Asia_deaths  Asia_recovered  \
# update_time
# 2020-01-22 09:00:00                 270.0          6.0             0.0
# 2020-01-22 09:30:00                   NaN          NaN             NaN
# 2020-01-22 10:00:00                   NaN          NaN             NaN
# 2020-01-22 10:30:00                   NaN          NaN             NaN
# 2020-01-22 11:00:00                   NaN          NaN             NaN
#
#                      Europe_confirmed_cases  Europe_deaths  Europe_recovered  \
# update_time
# 2020-01-22 09:00:00                     NaN            NaN               NaN
# 2020-01-22 09:30:00                     NaN            NaN               NaN
# 2020-01-22 10:00:00                     NaN            NaN               NaN
# 2020-01-22 10:30:00                     NaN            NaN               NaN
# 2020-01-22 11:00:00                     NaN            NaN               NaN
#
#                      Americas_confirmed_cases  Americas_deaths  \
# update_time
# 2020-01-22 09:00:00                       NaN              NaN
# 2020-01-22 09:30:00                       NaN              NaN
# 2020-01-22 10:00:00                       NaN              NaN
# 2020-01-22 10:30:00                       NaN              NaN
# 2020-01-22 11:00:00                       NaN              NaN
#
#                      Americas_recovered  Oceania_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                 NaN                      NaN
# 2020-01-22 09:30:00                 NaN                      NaN
# 2020-01-22 10:00:00                 NaN                      NaN
# 2020-01-22 10:30:00                 NaN                      NaN
# 2020-01-22 11:00:00                 NaN                      NaN
#
#                      Oceania_deaths  Oceania_recovered  \
# update_time
# 2020-01-22 09:00:00             NaN                NaN
# 2020-01-22 09:30:00             NaN                NaN
# 2020-01-22 10:00:00             NaN                NaN
# 2020-01-22 10:30:00             NaN                NaN
# 2020-01-22 11:00:00             NaN                NaN
#
#                      Africa_confirmed_cases  Africa_deaths  Africa_recovered
# update_time
# 2020-01-22 09:00:00                     NaN            NaN               NaN
# 2020-01-22 09:30:00                     NaN            NaN               NaN
# 2020-01-22 10:00:00                     NaN            NaN               NaN
# 2020-01-22 10:30:00                     NaN            NaN               NaN
# 2020-01-22 11:00:00                     NaN            NaN               NaN

# %%
df_final=df_final.fillna(0)
df_test_final=df_test_final.fillna(0)
df_final.head()
# Out:
#                      Asia_confirmed_cases  Asia_deaths  Asia_recovered  \
# update_time
# 2020-01-22 09:00:00                 270.0          6.0             0.0
# 2020-01-22 09:30:00                   0.0          0.0             0.0
# 2020-01-22 10:00:00                   0.0          0.0             0.0
# 2020-01-22 10:30:00                   0.0          0.0             0.0
# 2020-01-22 11:00:00                   0.0          0.0             0.0
#
#                      Europe_confirmed_cases  Europe_deaths  Europe_recovered  \
# update_time
# 2020-01-22 09:00:00                     0.0            0.0               0.0
# 2020-01-22 09:30:00                     0.0            0.0               0.0
# 2020-01-22 10:00:00                     0.0            0.0               0.0
# 2020-01-22 10:30:00                     0.0            0.0               0.0
# 2020-01-22 11:00:00                     0.0            0.0               0.0
#
#                      Americas_confirmed_cases  Americas_deaths  \
# update_time
# 2020-01-22 09:00:00                       0.0              0.0
# 2020-01-22 09:30:00                       0.0              0.0
# 2020-01-22 10:00:00                       0.0              0.0
# 2020-01-22 10:30:00                       0.0              0.0
# 2020-01-22 11:00:00                       0.0              0.0
#
#                      Americas_recovered  Oceania_confirmed_cases  ...  \
# update_time                                                       ...
# 2020-01-22 09:00:00                 0.0                      0.0  ...
# 2020-01-22 09:30:00                 0.0                      0.0  ...
# 2020-01-22 10:00:00                 0.0                      0.0  ...
# 2020-01-22 10:30:00                 0.0                      0.0  ...
# 2020-01-22 11:00:00                 0.0                      0.0  ...
#
#                      MI_Europe_recovered  MI_Americas_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                 True                         True
# 2020-01-22 09:30:00                 True                         True
# 2020-01-22 10:00:00                 True                         True
# 2020-01-22 10:30:00                 True                         True
# 2020-01-22 11:00:00                 True                         True
#
#                      MI_Americas_deaths  MI_Americas_recovered  \
# update_time
# 2020-01-22 09:00:00                True                   True
# 2020-01-22 09:30:00                True                   True
# 2020-01-22 10:00:00                True                   True
# 2020-01-22 10:30:00                True                   True
# 2020-01-22 11:00:00                True                   True
#
#                      MI_Oceania_confirmed_cases  MI_Oceania_deaths  \
# update_time
# 2020-01-22 09:00:00                        True               True
# 2020-01-22 09:30:00                        True               True
# 2020-01-22 10:00:00                        True               True
# 2020-01-22 10:30:00                        True               True
# 2020-01-22 11:00:00                        True               True
#
#                      MI_Oceania_recovered  MI_Africa_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                  True                       True
# 2020-01-22 09:30:00                  True                       True
# 2020-01-22 10:00:00                  True                       True
# 2020-01-22 10:30:00                  True                       True
# 2020-01-22 11:00:00                  True                       True
#
#                      MI_Africa_deaths  MI_Africa_recovered
# update_time
# 2020-01-22 09:00:00              True                 True
# 2020-01-22 09:30:00              True                 True
# 2020-01-22 10:00:00              True                 True
# 2020-01-22 10:30:00              True                 True
# 2020-01-22 11:00:00              True                 True
#
# [5 rows x 30 columns]

# %%
df_final.to_csv(OUTPUT+'_training.csv', index = True)
df_test_final.to_csv(OUTPUT+ '_test.csv', index = True)
