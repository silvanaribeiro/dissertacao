# %% [markdown]
# ## This notebook inputs the missing values using Mean Imputation

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import SimpleImputer

# %% [markdown]
# #### Choose wether the imputation should be done on the data set with daily or weekly granularity

# %%
INPUT, OUTPUT = 'output/\CompleteCovid', 'output/\MeanCovidImputed'

# %%
df = pd.read_csv(r'output\/CompleteCovid.csv',index_col=0)
df_train = df.loc['2020-01-22 09:00:00':'2020-02-26 02:00:00'].dropna(how='all', axis=1) #Selecting training data
df_test = df.loc['2020-02-26 02:30:00':, df_train.columns] #Selecting test data
df = df_train

# %%
df.tail()
# Out:
#                      Asia_confirmed_cases  Asia_deaths  Asia_recovered  \
# update_time
# 2020-02-26 00:00:00                 121.0          1.0            88.0
# 2020-02-26 00:30:00                 400.0          4.0           235.0
# 2020-02-26 01:00:00                 934.0          1.0           719.0
# 2020-02-26 01:30:00                   NaN          NaN             NaN
# 2020-02-26 02:00:00                   NaN          NaN             NaN
#
#                      Europe_confirmed_cases  Europe_deaths  Europe_recovered  \
# update_time
# 2020-02-26 00:00:00                     NaN            NaN               NaN
# 2020-02-26 00:30:00                     NaN            NaN               NaN
# 2020-02-26 01:00:00                     NaN            NaN               NaN
# 2020-02-26 01:30:00                     NaN            NaN               NaN
# 2020-02-26 02:00:00                     NaN            NaN               NaN
#
#                      Americas_confirmed_cases  Americas_deaths  \
# update_time
# 2020-02-26 00:00:00                       NaN              NaN
# 2020-02-26 00:30:00                       NaN              NaN
# 2020-02-26 01:00:00                       NaN              NaN
# 2020-02-26 01:30:00                       NaN              NaN
# 2020-02-26 02:00:00                       NaN              NaN
#
#                      Americas_recovered  Oceania_confirmed_cases  \
# update_time
# 2020-02-26 00:00:00                 NaN                      NaN
# 2020-02-26 00:30:00                 NaN                      NaN
# 2020-02-26 01:00:00                 NaN                      NaN
# 2020-02-26 01:30:00                 NaN                      NaN
# 2020-02-26 02:00:00                 NaN                      NaN
#
#                      Oceania_deaths  Oceania_recovered  \
# update_time
# 2020-02-26 00:00:00             NaN                NaN
# 2020-02-26 00:30:00             NaN                NaN
# 2020-02-26 01:00:00             NaN                NaN
# 2020-02-26 01:30:00             NaN                NaN
# 2020-02-26 02:00:00             NaN                NaN
#
#                      Africa_confirmed_cases  Africa_deaths  Africa_recovered
# update_time
# 2020-02-26 00:00:00                     NaN            NaN               NaN
# 2020-02-26 00:30:00                     NaN            NaN               NaN
# 2020-02-26 01:00:00                     NaN            NaN               NaN
# 2020-02-26 01:30:00                     NaN            NaN               NaN
# 2020-02-26 02:00:00                     NaN            NaN               NaN

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(df)
# Out:
# SimpleImputer()

# %%
df_imputed = imp.transform(df)
df_test_imputed = imp.transform(df_test)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)
df_test_final = pd.DataFrame(data=df_test_imputed, index=df_test.index, columns=df_test.columns)

# %%
df_final.head()
# Out:
#                      Asia_confirmed_cases  Asia_deaths  Asia_recovered  \
# update_time
# 2020-01-22 09:00:00            270.000000     6.000000        0.000000
# 2020-01-22 09:30:00           2260.259178    60.410111      315.506993
# 2020-01-22 10:00:00           2260.259178    60.410111      315.506993
# 2020-01-22 10:30:00           2260.259178    60.410111      315.506993
# 2020-01-22 11:00:00           2260.259178    60.410111      315.506993
#
#                      Europe_confirmed_cases  Europe_deaths  Europe_recovered  \
# update_time
# 2020-01-22 09:00:00               30.361111       0.694444          2.361111
# 2020-01-22 09:30:00               30.361111       0.694444          2.361111
# 2020-01-22 10:00:00               30.361111       0.694444          2.361111
# 2020-01-22 10:30:00               30.361111       0.694444          2.361111
# 2020-01-22 11:00:00               30.361111       0.694444          2.361111
#
#                      Americas_confirmed_cases  Americas_deaths  \
# update_time
# 2020-01-22 09:00:00                  6.159091              0.0
# 2020-01-22 09:30:00                  6.159091              0.0
# 2020-01-22 10:00:00                  6.159091              0.0
# 2020-01-22 10:30:00                  6.159091              0.0
# 2020-01-22 11:00:00                  6.159091              0.0
#
#                      Americas_recovered  Oceania_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00            0.272727                 6.647059
# 2020-01-22 09:30:00            0.272727                 6.647059
# 2020-01-22 10:00:00            0.272727                 6.647059
# 2020-01-22 10:30:00            0.272727                 6.647059
# 2020-01-22 11:00:00            0.272727                 6.647059
#
#                      Oceania_deaths  Oceania_recovered  \
# update_time
# 2020-01-22 09:00:00             0.0           0.529412
# 2020-01-22 09:30:00             0.0           0.529412
# 2020-01-22 10:00:00             0.0           0.529412
# 2020-01-22 10:30:00             0.0           0.529412
# 2020-01-22 11:00:00             0.0           0.529412
#
#                      Africa_confirmed_cases  Africa_deaths  Africa_recovered
# update_time
# 2020-01-22 09:00:00                     1.0            0.0               0.0
# 2020-01-22 09:30:00                     1.0            0.0               0.0
# 2020-01-22 10:00:00                     1.0            0.0               0.0
# 2020-01-22 10:30:00                     1.0            0.0               0.0
# 2020-01-22 11:00:00                     1.0            0.0               0.0

# %%
df_final.to_csv(OUTPUT+'_training.csv', index = True)
df_test_final.to_csv(OUTPUT+ '_test.csv', index = True)

# %%
df_imputed.shape
# Out:
# (1667, 15)
