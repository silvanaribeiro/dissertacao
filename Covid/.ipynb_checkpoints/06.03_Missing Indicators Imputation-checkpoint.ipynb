# %% [markdown]
# ## This notebook inputs the missing values using Missing Indicators

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import MissingIndicator

# %% [markdown]
# #### Choose wether the imputation should be done on the data set with daily or weekly granularity

# %%
INPUT, OUTPUT = 'output/\CompleteCovid', 'output/\MIICovidImputed'

# %%
df = pd.read_csv(r'output\/CompleteCovid.csv',index_col=0)
df_train = df.loc['2020-01-22 09:00:00':'2020-02-26 02:00:00'].dropna(how='all', axis=1) #Selecting training data
df_test = df.loc['2020-02-26 03:00:00':, df_train.columns] #Selecting test data
df = df_train

# %%
indicator = MissingIndicator(missing_values=np.nan, features="all")

# %%
indicator.fit(df)
mask_all = indicator.transform(df)
mask_test_all = indicator.transform(df_test)

# %%
df_masks = pd.DataFrame(data=mask_all, index=df.index, columns=df.columns)
df_test_masks = pd.DataFrame(data=mask_test_all, index=df_test.index, columns=df_test.columns)

# %%
df_masks = df_masks.add_prefix('MI_')
df_test_masks = df_test_masks.add_prefix('MI_')

# %%
df_final = pd.concat([df, df_masks], axis=1, join='outer')
df_test_final = pd.concat([df_test, df_test_masks], axis=1, join='outer')

# %%
df_final.head()
# Out:
#                      Hubei_latitude  Hubei_longitude  Hubei_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00        35.86166       104.195397                  270.0
# 2020-01-22 10:00:00             NaN              NaN                    NaN
# 2020-01-22 11:00:00             NaN              NaN                    NaN
# 2020-01-22 12:00:00             NaN              NaN                    NaN
# 2020-01-22 13:00:00             NaN              NaN                    NaN
#
#                      Hubei_deaths  Hubei_recovered  Guangdong_latitude  \
# update_time
# 2020-01-22 09:00:00           6.0              0.0            35.86166
# 2020-01-22 10:00:00           NaN              NaN                 NaN
# 2020-01-22 11:00:00           NaN              NaN                 NaN
# 2020-01-22 12:00:00           NaN              NaN                 NaN
# 2020-01-22 13:00:00           NaN              NaN                 NaN
#
#                      Guangdong_longitude  Guangdong_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00           104.195397                       17.0
# 2020-01-22 10:00:00                  NaN                        NaN
# 2020-01-22 11:00:00                  NaN                        NaN
# 2020-01-22 12:00:00                  NaN                        NaN
# 2020-01-22 13:00:00                  NaN                        NaN
#
#                      Guangdong_deaths  Guangdong_recovered  ...  \
# update_time                                                 ...
# 2020-01-22 09:00:00               0.0                  0.0  ...
# 2020-01-22 10:00:00               NaN                  NaN  ...
# 2020-01-22 11:00:00               NaN                  NaN  ...
# 2020-01-22 12:00:00               NaN                  NaN  ...
# 2020-01-22 13:00:00               NaN                  NaN  ...
#
#                      MI_Omaha, NE (From Diamond Princess)_latitude  \
# update_time
# 2020-01-22 09:00:00                                           True
# 2020-01-22 10:00:00                                           True
# 2020-01-22 11:00:00                                           True
# 2020-01-22 12:00:00                                           True
# 2020-01-22 13:00:00                                           True
#
#                      MI_Omaha, NE (From Diamond Princess)_longitude  \
# update_time
# 2020-01-22 09:00:00                                            True
# 2020-01-22 10:00:00                                            True
# 2020-01-22 11:00:00                                            True
# 2020-01-22 12:00:00                                            True
# 2020-01-22 13:00:00                                            True
#
#                      MI_Omaha, NE (From Diamond Princess)_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Omaha, NE (From Diamond Princess)_deaths  \
# update_time
# 2020-01-22 09:00:00                                         True
# 2020-01-22 10:00:00                                         True
# 2020-01-22 11:00:00                                         True
# 2020-01-22 12:00:00                                         True
# 2020-01-22 13:00:00                                         True
#
#                      MI_Omaha, NE (From Diamond Princess)_recovered  \
# update_time
# 2020-01-22 09:00:00                                            True
# 2020-01-22 10:00:00                                            True
# 2020-01-22 11:00:00                                            True
# 2020-01-22 12:00:00                                            True
# 2020-01-22 13:00:00                                            True
#
#                      MI_Unassigned Location (From Diamond Princess)_latitude  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_longitude  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_deaths  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_recovered
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
# [5 rows x 720 columns]

# %%
df.head()
# Out:
#                      Hubei_latitude  Hubei_longitude  Hubei_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00        35.86166       104.195397                  270.0
# 2020-01-22 10:00:00             NaN              NaN                    NaN
# 2020-01-22 11:00:00             NaN              NaN                    NaN
# 2020-01-22 12:00:00             NaN              NaN                    NaN
# 2020-01-22 13:00:00             NaN              NaN                    NaN
#
#                      Hubei_deaths  Hubei_recovered  Guangdong_latitude  \
# update_time
# 2020-01-22 09:00:00           6.0              0.0            35.86166
# 2020-01-22 10:00:00           NaN              NaN                 NaN
# 2020-01-22 11:00:00           NaN              NaN                 NaN
# 2020-01-22 12:00:00           NaN              NaN                 NaN
# 2020-01-22 13:00:00           NaN              NaN                 NaN
#
#                      Guangdong_longitude  Guangdong_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00           104.195397                       17.0
# 2020-01-22 10:00:00                  NaN                        NaN
# 2020-01-22 11:00:00                  NaN                        NaN
# 2020-01-22 12:00:00                  NaN                        NaN
# 2020-01-22 13:00:00                  NaN                        NaN
#
#                      Guangdong_deaths  Guangdong_recovered  ...  \
# update_time                                                 ...
# 2020-01-22 09:00:00               0.0                  0.0  ...
# 2020-01-22 10:00:00               NaN                  NaN  ...
# 2020-01-22 11:00:00               NaN                  NaN  ...
# 2020-01-22 12:00:00               NaN                  NaN  ...
# 2020-01-22 13:00:00               NaN                  NaN  ...
#
#                      Omaha, NE (From Diamond Princess)_latitude  \
# update_time
# 2020-01-22 09:00:00                                         NaN
# 2020-01-22 10:00:00                                         NaN
# 2020-01-22 11:00:00                                         NaN
# 2020-01-22 12:00:00                                         NaN
# 2020-01-22 13:00:00                                         NaN
#
#                      Omaha, NE (From Diamond Princess)_longitude  \
# update_time
# 2020-01-22 09:00:00                                          NaN
# 2020-01-22 10:00:00                                          NaN
# 2020-01-22 11:00:00                                          NaN
# 2020-01-22 12:00:00                                          NaN
# 2020-01-22 13:00:00                                          NaN
#
#                      Omaha, NE (From Diamond Princess)_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                                                NaN
# 2020-01-22 10:00:00                                                NaN
# 2020-01-22 11:00:00                                                NaN
# 2020-01-22 12:00:00                                                NaN
# 2020-01-22 13:00:00                                                NaN
#
#                      Omaha, NE (From Diamond Princess)_deaths  \
# update_time
# 2020-01-22 09:00:00                                       NaN
# 2020-01-22 10:00:00                                       NaN
# 2020-01-22 11:00:00                                       NaN
# 2020-01-22 12:00:00                                       NaN
# 2020-01-22 13:00:00                                       NaN
#
#                      Omaha, NE (From Diamond Princess)_recovered  \
# update_time
# 2020-01-22 09:00:00                                          NaN
# 2020-01-22 10:00:00                                          NaN
# 2020-01-22 11:00:00                                          NaN
# 2020-01-22 12:00:00                                          NaN
# 2020-01-22 13:00:00                                          NaN
#
#                      Unassigned Location (From Diamond Princess)_latitude  \
# update_time
# 2020-01-22 09:00:00                                                NaN
# 2020-01-22 10:00:00                                                NaN
# 2020-01-22 11:00:00                                                NaN
# 2020-01-22 12:00:00                                                NaN
# 2020-01-22 13:00:00                                                NaN
#
#                      Unassigned Location (From Diamond Princess)_longitude  \
# update_time
# 2020-01-22 09:00:00                                                NaN
# 2020-01-22 10:00:00                                                NaN
# 2020-01-22 11:00:00                                                NaN
# 2020-01-22 12:00:00                                                NaN
# 2020-01-22 13:00:00                                                NaN
#
#                      Unassigned Location (From Diamond Princess)_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                                                NaN
# 2020-01-22 10:00:00                                                NaN
# 2020-01-22 11:00:00                                                NaN
# 2020-01-22 12:00:00                                                NaN
# 2020-01-22 13:00:00                                                NaN
#
#                      Unassigned Location (From Diamond Princess)_deaths  \
# update_time
# 2020-01-22 09:00:00                                                NaN
# 2020-01-22 10:00:00                                                NaN
# 2020-01-22 11:00:00                                                NaN
# 2020-01-22 12:00:00                                                NaN
# 2020-01-22 13:00:00                                                NaN
#
#                      Unassigned Location (From Diamond Princess)_recovered
# update_time
# 2020-01-22 09:00:00                                                NaN
# 2020-01-22 10:00:00                                                NaN
# 2020-01-22 11:00:00                                                NaN
# 2020-01-22 12:00:00                                                NaN
# 2020-01-22 13:00:00                                                NaN
#
# [5 rows x 360 columns]

# %%
df_final=df_final.fillna(0)
df_test_final=df_test_final.fillna(0)
df_final.head()
# Out:
#                      Hubei_latitude  Hubei_longitude  Hubei_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00        35.86166       104.195397                  270.0
# 2020-01-22 10:00:00         0.00000         0.000000                    0.0
# 2020-01-22 11:00:00         0.00000         0.000000                    0.0
# 2020-01-22 12:00:00         0.00000         0.000000                    0.0
# 2020-01-22 13:00:00         0.00000         0.000000                    0.0
#
#                      Hubei_deaths  Hubei_recovered  Guangdong_latitude  \
# update_time
# 2020-01-22 09:00:00           6.0              0.0            35.86166
# 2020-01-22 10:00:00           0.0              0.0             0.00000
# 2020-01-22 11:00:00           0.0              0.0             0.00000
# 2020-01-22 12:00:00           0.0              0.0             0.00000
# 2020-01-22 13:00:00           0.0              0.0             0.00000
#
#                      Guangdong_longitude  Guangdong_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00           104.195397                       17.0
# 2020-01-22 10:00:00             0.000000                        0.0
# 2020-01-22 11:00:00             0.000000                        0.0
# 2020-01-22 12:00:00             0.000000                        0.0
# 2020-01-22 13:00:00             0.000000                        0.0
#
#                      Guangdong_deaths  Guangdong_recovered  ...  \
# update_time                                                 ...
# 2020-01-22 09:00:00               0.0                  0.0  ...
# 2020-01-22 10:00:00               0.0                  0.0  ...
# 2020-01-22 11:00:00               0.0                  0.0  ...
# 2020-01-22 12:00:00               0.0                  0.0  ...
# 2020-01-22 13:00:00               0.0                  0.0  ...
#
#                      MI_Omaha, NE (From Diamond Princess)_latitude  \
# update_time
# 2020-01-22 09:00:00                                           True
# 2020-01-22 10:00:00                                           True
# 2020-01-22 11:00:00                                           True
# 2020-01-22 12:00:00                                           True
# 2020-01-22 13:00:00                                           True
#
#                      MI_Omaha, NE (From Diamond Princess)_longitude  \
# update_time
# 2020-01-22 09:00:00                                            True
# 2020-01-22 10:00:00                                            True
# 2020-01-22 11:00:00                                            True
# 2020-01-22 12:00:00                                            True
# 2020-01-22 13:00:00                                            True
#
#                      MI_Omaha, NE (From Diamond Princess)_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Omaha, NE (From Diamond Princess)_deaths  \
# update_time
# 2020-01-22 09:00:00                                         True
# 2020-01-22 10:00:00                                         True
# 2020-01-22 11:00:00                                         True
# 2020-01-22 12:00:00                                         True
# 2020-01-22 13:00:00                                         True
#
#                      MI_Omaha, NE (From Diamond Princess)_recovered  \
# update_time
# 2020-01-22 09:00:00                                            True
# 2020-01-22 10:00:00                                            True
# 2020-01-22 11:00:00                                            True
# 2020-01-22 12:00:00                                            True
# 2020-01-22 13:00:00                                            True
#
#                      MI_Unassigned Location (From Diamond Princess)_latitude  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_longitude  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_confirmed_cases  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_deaths  \
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
#                      MI_Unassigned Location (From Diamond Princess)_recovered
# update_time
# 2020-01-22 09:00:00                                               True
# 2020-01-22 10:00:00                                               True
# 2020-01-22 11:00:00                                               True
# 2020-01-22 12:00:00                                               True
# 2020-01-22 13:00:00                                               True
#
# [5 rows x 720 columns]

# %%
df_final.to_csv(OUTPUT+'_training.csv', index = True)
df_test_final.to_csv(OUTPUT+ '_test.csv', index = True)
