# %% [markdown]
# ## This notebook inputs the missing values using Mean Imputation

# %%
import pandas as pd
from datetime import datetime
import numpy as np
from sklearn.impute import SimpleImputer

# %% [markdown]
# #### Choose wether the imputation should be done on the data set with daily or weekly granularity

# %%
INPUT, OUTPUT = 'output/CompleteDengue.csv', 'output/\MeanDengueImputed'

# %%
df = pd.read_csv(r'output\/CompleteDengue.csv',index_col=0)
df_train = df.loc['1990-04-30':'2006-07-16'].dropna(how='all', axis=1) #Selecting training data
df_test = df.loc['2006-07-23':, df_train.columns] #Selecting test data
df = df_train

# %%
df.tail()
# Out:
#             sj_ndvi_ne  sj_ndvi_nw  sj_ndvi_se  sj_ndvi_sw  \
# 2006-06-18   -0.010033   -0.057200    0.151700    0.149883
# 2006-06-25    0.025500    0.042767    0.107043    0.110557
# 2006-07-02    0.103500    0.197700    0.133871    0.122943
# 2006-07-09    0.063875    0.054850    0.177033    0.133333
# 2006-07-16    0.019300    0.069233    0.123271    0.105829
#
#             sj_precipitation_amt_mm  sj_reanalysis_air_temp_k  \
# 2006-06-18                     7.56                301.021429
# 2006-06-25                    19.95                300.478571
# 2006-07-02                   111.15                300.504286
# 2006-07-09                    52.63                300.584286
# 2006-07-16                    56.73                300.262857
#
#             sj_reanalysis_avg_temp_k  sj_reanalysis_dew_point_temp_k  \
# 2006-06-18                301.142857                      296.361429
# 2006-06-25                300.535714                      296.642857
# 2006-07-02                300.635714                      297.161429
# 2006-07-09                300.607143                      296.518571
# 2006-07-16                300.428571                      296.780000
#
#             sj_reanalysis_max_air_temp_k  sj_reanalysis_min_air_temp_k  ...  \
# 2006-06-18                         303.3                         299.6  ...
# 2006-06-25                         302.4                         298.7  ...
# 2006-07-02                         303.0                         299.0  ...
# 2006-07-09                         302.4                         298.8  ...
# 2006-07-16                         303.0                         298.4  ...
#
#             iq_reanalysis_precip_amt_kg_per_m2  \
# 2006-06-18                               21.50
# 2006-06-25                               27.29
# 2006-07-02                                9.16
# 2006-07-09                               13.62
# 2006-07-16                                1.80
#
#             iq_reanalysis_relative_humidity_percent  \
# 2006-06-18                                87.214286
# 2006-06-25                                88.471429
# 2006-07-02                                83.467143
# 2006-07-09                                90.432857
# 2006-07-16                                77.271429
#
#             iq_reanalysis_sat_precip_amt_mm  \
# 2006-06-18                            84.99
# 2006-06-25                            71.69
# 2006-07-02                            17.21
# 2006-07-09                            20.72
# 2006-07-16                             1.17
#
#             iq_reanalysis_specific_humidity_g_per_kg  iq_reanalysis_tdtr_k  \
# 2006-06-18                                 16.258571             10.071429
# 2006-06-25                                 15.801429             10.785714
# 2006-07-02                                 15.020000             10.742857
# 2006-07-09                                 16.005714              7.971429
# 2006-07-16                                 14.417143             11.428571
#
#             iq_station_avg_temp_c  iq_station_diur_temp_rng_c  \
# 2006-06-18                  28.10                       12.70
# 2006-06-25                  26.60                       10.35
# 2006-07-02                  27.20                       10.30
# 2006-07-09                  26.70                        9.40
# 2006-07-16                  26.25                       10.40
#
#             iq_station_max_temp_c  iq_station_min_temp_c  iq_station_precip_mm
# 2006-06-18                   34.4                   21.4                  79.5
# 2006-06-25                   32.5                   20.4                  74.9
# 2006-07-02                   33.4                   19.8                  21.9
# 2006-07-09                   33.0                   21.7                 110.6
# 2006-07-16                   33.1                   20.6                   0.5
#
# [5 rows x 40 columns]

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(df)
# Out:
# SimpleImputer()

# %%
df_imputed = imp.transform(df)
df_test_imputed = imp.transform(df_test)

# %%
df_final = pd.DataFrame(data=df_imputed, index=df.index, columns=df.columns)
df_test_final = pd.DataFrame(data=df_test_imputed, index=df_test.index, columns=df_test.columns)

# %%
df_final.head()
# Out:
#             sj_ndvi_ne  sj_ndvi_nw  sj_ndvi_se  sj_ndvi_sw  \
# 1990-04-30    0.122600    0.103725    0.198483    0.177617
# 1990-05-07    0.169900    0.142175    0.162357    0.155486
# 1990-05-14    0.032250    0.172967    0.157200    0.170843
# 1990-05-21    0.128633    0.245067    0.227557    0.235886
# 1990-05-28    0.196200    0.262200    0.251200    0.247340
#
#             sj_precipitation_amt_mm  sj_reanalysis_air_temp_k  \
# 1990-04-30                    12.42                297.572857
# 1990-05-07                    22.82                298.211429
# 1990-05-14                    34.54                298.781429
# 1990-05-21                    15.36                298.987143
# 1990-05-28                     7.52                299.518571
#
#             sj_reanalysis_avg_temp_k  sj_reanalysis_dew_point_temp_k  \
# 1990-04-30                297.742857                      292.414286
# 1990-05-07                298.442857                      293.951429
# 1990-05-14                298.878571                      295.434286
# 1990-05-21                299.228571                      295.310000
# 1990-05-28                299.664286                      295.821429
#
#             sj_reanalysis_max_air_temp_k  sj_reanalysis_min_air_temp_k  ...  \
# 1990-04-30                         299.8                         295.9  ...
# 1990-05-07                         300.9                         296.4  ...
# 1990-05-14                         300.5                         297.3  ...
# 1990-05-21                         301.4                         297.0  ...
# 1990-05-28                         301.9                         297.5  ...
#
#             iq_reanalysis_precip_amt_kg_per_m2  \
# 1990-04-30                           52.260607
# 1990-05-07                           52.260607
# 1990-05-14                           52.260607
# 1990-05-21                           52.260607
# 1990-05-28                           52.260607
#
#             iq_reanalysis_relative_humidity_percent  \
# 1990-04-30                                87.628658
# 1990-05-07                                87.628658
# 1990-05-14                                87.628658
# 1990-05-21                                87.628658
# 1990-05-28                                87.628658
#
#             iq_reanalysis_sat_precip_amt_mm  \
# 1990-04-30                        62.473099
# 1990-05-07                        62.473099
# 1990-05-14                        62.473099
# 1990-05-21                        62.473099
# 1990-05-28                        62.473099
#
#             iq_reanalysis_specific_humidity_g_per_kg  iq_reanalysis_tdtr_k  \
# 1990-04-30                                 16.842492              9.477088
# 1990-05-07                                 16.842492              9.477088
# 1990-05-14                                 16.842492              9.477088
# 1990-05-21                                 16.842492              9.477088
# 1990-05-28                                 16.842492              9.477088
#
#             iq_station_avg_temp_c  iq_station_diur_temp_rng_c  \
# 1990-04-30              27.507751                   10.568408
# 1990-05-07              27.507751                   10.568408
# 1990-05-14              27.507751                   10.568408
# 1990-05-21              27.507751                   10.568408
# 1990-05-28              27.507751                   10.568408
#
#             iq_station_max_temp_c  iq_station_min_temp_c  iq_station_precip_mm
# 1990-04-30              33.954693                   21.2             66.254045
# 1990-05-07              33.954693                   21.2             66.254045
# 1990-05-14              33.954693                   21.2             66.254045
# 1990-05-21              33.954693                   21.2             66.254045
# 1990-05-28              33.954693                   21.2             66.254045
#
# [5 rows x 40 columns]

# %%
df_final.to_csv(OUTPUT+'_training.csv', index = True)
df_test_final.to_csv(OUTPUT+ '_test.csv', index = True)

# %%
df_imputed.shape
# Out:
# (844, 40)
